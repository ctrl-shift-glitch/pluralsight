# %%
# !pip install tensorflow

# %%
# !pip install graphviz

# %%
# !pip install hiddenlayer

# %%
import numpy as np
import torch
import torch.nn as nn

# %%
W = torch.randn(6)

x = torch.tensor([10.0, 10.0, 10.0, 10.0, 10.0, 10.0])

b = torch.tensor(3)

# %%
W
# Out:
# tensor([ 1.8181, -0.1834, -1.1854, -0.3314,  2.1826, -0.0837])

# %%
y = W*x + b

# %%
y
# Out:
# tensor([21.1810,  1.1660, -8.8536, -0.3143, 24.8260,  2.1634])

# %%
W*x
# Out:
# tensor([ 18.1810,  -1.8340, -11.8536,  -3.3143,  21.8260,  -0.8366])

# %%
b
# Out:
# tensor(3)

# %%
W1 = torch.tensor(6)
W2 = torch.tensor(6)
W3 = torch.tensor(6)

x1 = torch.tensor([2, 2, 2])
x2 = torch.tensor([3, 3, 3])
x3 = torch.tensor([4, 4, 4])

b = torch.tensor(10)

# %%
W1, W2, W3
# Out:
# (tensor(6), tensor(6), tensor(6))

# %%
intermediate_value = W1 * x1 + W2 * x2

intermediate_value
# Out:
# tensor([30, 30, 30])

# %%
final_value =  W1 * x1 + W2 * x2 + W3 * x3 + b

final_value
# Out:
# tensor([64, 64, 64])

# %%
import hiddenlayer as hl

# %%
x_train = np.array ([[4.7], [2.4], [7.5], [7.1], [4.3], [7.816], 
                    [8.9], [5.2], [8.59], [2.1], [8],
                    [10], [4.5], [6], [4]],
                    dtype = np.float32)

y_train = np.array ([[2.6], [1.6], [3.09], [2.4], [2.4], [3.357],
                    [2.6], [1.96], [3.53], [1.76], [3.2],
                    [3.5], [1.6], [2.5], [2.2]], 
                    dtype = np.float32)

# %%
X_train = torch.tensor(x_train)
Y_train = torch.tensor(y_train)

X_train.shape
# Out:
# torch.Size([15, 1])

# %%
inp = 1
out = 1

hid = 100

# %%
model1 = torch.nn.Sequential(torch.nn.Linear(inp, hid),torch.nn.Linear(hid, out))

# %%
hl.build_graph(model1, torch.zeros([15, 1]))

# %%
hl.build_graph(model1, torch.zeros([1]))

# %%
model2 = torch.nn.Sequential(torch.nn.Linear(inp, hid),
                            torch.nn.Linear(hid, hid),
                            torch.nn.Sigmoid(),
                            torch.nn.Linear(hid, out ))

# %%
hl.build_graph(model2, torch.zeros([15, 1]))

# %%
hl.build_graph(model2, torch.zeros([1]))
